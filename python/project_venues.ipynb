# %% [markdown]
# # NFL Teams

# %%
# Install geopy
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in c:\users\sarap\anaconda3\lib\site-packages (2.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\sarap\anaconda3\lib\site-packages (from geopy) (2.0)

# %%
# Import dependencies and setup
import pandas as pd
import requests
from pprint import pprint
import geopy
from geopy.geocoders import Nominatim

# %%
# Create empty lists to store data
team_id=[]
team_abbr=[]
team_name=[]
team_venue=[]
venue_id=[]
venue_city=[]
venue_state=[]
venue_zip=[]
venue_capacity=[]
venue_grass=[]
venue_indoor=[]
team_logo=[]

# Create For loop to extract data from API
for x in range(1,35):
    
    url='http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/seasons/2022/teams/'+ str(x) +'?lang=en&region=us'
    response=(requests.get(url).json())
    
    try:     

        # Retrieve the relevant information       
        team_id.append(response['id'])
        team_abbr.append(response['abbreviation'])
        team_name.append(response['displayName'])
        team_venue.append(response['venue']['fullName'])
        venue_id.append(response['venue']['id'])
        venue_city.append(response['venue']['address']['city'])
        venue_state.append(response['venue']['address']['state'])
        venue_zip.append(response['venue']['address']['zipCode'])
        venue_capacity.append(response['venue']['capacity'])
        venue_grass.append(response['venue']['grass'])
        venue_indoor.append(response['venue']['indoor'])
        team_logo.append(response['logos'][0]['href'])
    
    # Handle KeyErrors
    except KeyError:
        value="N/A"
        team_venue.append(value)
        venue_id.append(value)
        venue_city.append(value)
        venue_state.append(value)
        venue_zip.append(value)
        venue_capacity.append(value)
        venue_grass.append(value)
        venue_indoor.append(value)
        team_logo.append(value)
    
# Create dictionaries and append extracted data to the dictionary
team={
    'Team_id':team_id,
    'Abbreviation':team_abbr,
    'Team_Name':team_name,
    'Venue_id':venue_id,
    'Team_logo':team_logo
    }

venue={
    'Venue_id':venue_id,
    'Team_Venue':team_venue,
    'Venue_City':venue_city,
    'Venue_State':venue_state,
    'Venue_ZipCode':venue_zip,
    'Venue_Capacity':venue_capacity,
    'Venue_Grass':venue_grass,
    'Venue_Indoor':venue_indoor}

# %%
# Create the Teams dataframe
team_df=pd.DataFrame(team)

# Show the dataframe
team_df.head()
# Out:
#   Team_id Abbreviation           Team_Name Venue_id  \
# 0       1          ATL     Atlanta Falcons     5348
# 1       2          BUF       Buffalo Bills     3883
# 2       3          CHI       Chicago Bears     3933
# 3       4          CIN  Cincinnati Bengals     3874
# 4       5          CLE    Cleveland Browns     3679
#
#                                            Team_logo
# 0  https://a.espncdn.com/i/teamlogos/nfl/500/atl.png
# 1  https://a.espncdn.com/i/teamlogos/nfl/500/buf.png
# 2  https://a.espncdn.com/i/teamlogos/nfl/500/chi.png
# 3  https://a.espncdn.com/i/teamlogos/nfl/500/cin.png
# 4  https://a.espncdn.com/i/teamlogos/nfl/500/cle.png

# %%
# Create the Venue dataframe
venue_df=pd.DataFrame(venue)

# Show the dataframe
venue_df.head()
# Out:
#   Venue_id                Team_Venue    Venue_City Venue_State Venue_ZipCode  \
# 0     5348     Mercedes-Benz Stadium       Atlanta          GA         30313
# 1     3883          Highmark Stadium  Orchard Park          NY         14127
# 2     3933             Soldier Field       Chicago          IL         60605
# 3     3874            Paycor Stadium    Cincinnati          OH         45202
# 4     3679  Cleveland Browns Stadium     Cleveland          OH         44114
#
#   Venue_Capacity Venue_Grass Venue_Indoor
# 0          75000       False         True
# 1          71621       False        False
# 2          61500        True        False
# 3          65515       False        False
# 4          67431        True        False

# %%
# Merge the team and venue dataframes
merged_teamvenue_df = pd.merge(team_df, venue_df, on="Venue_id", how='left')

# %%
# Clean the merged datafra,e
teamvenue_cleaned=merged_teamvenue_df.loc[(merged_teamvenue_df['Team_id']!='31') & (merged_teamvenue_df['Team_id']!='32')]

# Show the cleaned dataframe
teamvenue_cleaned.head()
# Out:
#   Team_id Abbreviation           Team_Name Venue_id  \
# 0       1          ATL     Atlanta Falcons     5348
# 1       2          BUF       Buffalo Bills     3883
# 2       3          CHI       Chicago Bears     3933
# 3       4          CIN  Cincinnati Bengals     3874
# 4       5          CLE    Cleveland Browns     3679
#
#                                            Team_logo  \
# 0  https://a.espncdn.com/i/teamlogos/nfl/500/atl.png
# 1  https://a.espncdn.com/i/teamlogos/nfl/500/buf.png
# 2  https://a.espncdn.com/i/teamlogos/nfl/500/chi.png
# 3  https://a.espncdn.com/i/teamlogos/nfl/500/cin.png
# 4  https://a.espncdn.com/i/teamlogos/nfl/500/cle.png
#
#                  Team_Venue    Venue_City Venue_State Venue_ZipCode  \
# 0     Mercedes-Benz Stadium       Atlanta          GA         30313
# 1          Highmark Stadium  Orchard Park          NY         14127
# 2             Soldier Field       Chicago          IL         60605
# 3            Paycor Stadium    Cincinnati          OH         45202
# 4  Cleveland Browns Stadium     Cleveland          OH         44114
#
#   Venue_Capacity Venue_Grass Venue_Indoor
# 0          75000       False         True
# 1          71621       False        False
# 2          61500        True        False
# 3          65515       False        False
# 4          67431        True        False

# %%
# Convert the datatype for required columns
teamvenue_cleaned['Venue_ZipCode']=teamvenue_cleaned['Venue_ZipCode'].astype(int)

# Show the details
teamvenue_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34 entries, 0 to 37
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Team_id         34 non-null     object
#  1   Abbreviation    34 non-null     object
#  2   Team_Name       34 non-null     object
#  3   Venue_id        34 non-null     object
#  4   Team_logo       34 non-null     object
#  5   Team_Venue      34 non-null     object
#  6   Venue_City      34 non-null     object
#  7   Venue_State     34 non-null     object
#  8   Venue_ZipCode   34 non-null     int32
#  9   Venue_Capacity  34 non-null     object
#  10  Venue_Grass     34 non-null     object
#  11  Venue_Indoor    34 non-null     object
# dtypes: int32(1), object(11)
# memory usage: 3.3+ KB
# C:\Users\sarap\AppData\Local\Temp\ipykernel_3144\1951035500.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teamvenue_cleaned['Venue_ZipCode']=teamvenue_cleaned['Venue_ZipCode'].astype(int)

# %%
# Get the locations' latitude and longitude values from GeoPy
geolocator = Nominatim(user_agent="NFL-app")

# Add location data to the dataframe
for index, row in teamvenue_cleaned.iterrows():
    zip = str(row['Venue_ZipCode'])
    zip_true = zip[:5]
    address = zip_true + ", USA"  
    location = geolocator.geocode(address)
    teamvenue_cleaned.loc[index, "Latitude"] = location.latitude
    teamvenue_cleaned.loc[index, "Longitude"] = location.longitude
# Out:
# C:\Users\sarap\AppData\Local\Temp\ipykernel_3144\3740815048.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teamvenue_cleaned.loc[index, "Latitude"] = location.latitude
# C:\Users\sarap\AppData\Local\Temp\ipykernel_3144\3740815048.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teamvenue_cleaned.loc[index, "Longitude"] = location.longitude

# %%
# Show the data types
teamvenue_cleaned.dtypes
# Out:
# Team_id            object
# Abbreviation       object
# Team_Name          object
# Venue_id           object
# Team_logo          object
# Team_Venue         object
# Venue_City         object
# Venue_State        object
# Venue_ZipCode       int32
# Venue_Capacity     object
# Venue_Grass        object
# Venue_Indoor       object
# Latitude          float64
# Longitude         float64
# dtype: object

# %%
# Combine latitude and longitude values to one columns
teamvenue_cleaned.loc[:, 'Location'] = teamvenue_cleaned.apply(lambda row: (row['Latitude'], 
                                                                            row['Longitude']), axis=1)
# Out:
# C:\Users\sarap\AppData\Local\Temp\ipykernel_3144\2807766463.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teamvenue_cleaned.loc[:, 'Location'] = teamvenue_cleaned.apply(lambda row: (row['Latitude'],

# %%
# Show the new dataset
teamvenue_cleaned.head()
# Out:
#   Team_id Abbreviation           Team_Name Venue_id  \
# 0       1          ATL     Atlanta Falcons     5348
# 1       2          BUF       Buffalo Bills     3883
# 2       3          CHI       Chicago Bears     3933
# 3       4          CIN  Cincinnati Bengals     3874
# 4       5          CLE    Cleveland Browns     3679
#
#                                            Team_logo  \
# 0  https://a.espncdn.com/i/teamlogos/nfl/500/atl.png
# 1  https://a.espncdn.com/i/teamlogos/nfl/500/buf.png
# 2  https://a.espncdn.com/i/teamlogos/nfl/500/chi.png
# 3  https://a.espncdn.com/i/teamlogos/nfl/500/cin.png
# 4  https://a.espncdn.com/i/teamlogos/nfl/500/cle.png
#
#                  Team_Venue    Venue_City Venue_State  Venue_ZipCode  \
# 0     Mercedes-Benz Stadium       Atlanta          GA          30313
# 1          Highmark Stadium  Orchard Park          NY          14127
# 2             Soldier Field       Chicago          IL          60605
# 3            Paycor Stadium    Cincinnati          OH          45202
# 4  Cleveland Browns Stadium     Cleveland          OH          44114
#
#   Venue_Capacity Venue_Grass Venue_Indoor   Latitude  Longitude  \
# 0          75000       False         True  33.762932 -84.396061
# 1          71621       False        False  42.763758 -78.750270
# 2          61500        True        False  41.870307 -87.626925
# 3          65515       False        False  39.107778 -84.510299
# 4          67431        True        False  41.506159 -81.680961
#
#                                    Location
# 0   (33.76293171583055, -84.39606140301004)
# 1   (42.76375798202035, -78.75026984439712)
# 2  (41.870307417105266, -87.62692521008772)
# 3  (39.107778355093096, -84.51029897382256)
# 4   (41.50615907683215, -81.68096072624114)

# %%
# Drop the duplicate rows
teamvenue_cleaned = teamvenue_cleaned.drop_duplicates(subset=None, keep='first', 
                                                      inplace=False, ignore_index=False)

# %%
# Show the updated dataset
teamvenue_cleaned
# Out:
#    Team_id Abbreviation              Team_Name Venue_id  \
# 0        1          ATL        Atlanta Falcons     5348
# 1        2          BUF          Buffalo Bills     3883
# 2        3          CHI          Chicago Bears     3933
# 3        4          CIN     Cincinnati Bengals     3874
# 4        5          CLE       Cleveland Browns     3679
# 5        6          DAL         Dallas Cowboys     3687
# 6        7          DEN         Denver Broncos     3937
# 7        8          DET          Detroit Lions     3727
# 8        9           GB      Green Bay Packers     3798
# 9       10          TEN       Tennessee Titans     3810
# 10      11          IND     Indianapolis Colts     3812
# 11      12           KC     Kansas City Chiefs     3622
# 12      13           LV      Las Vegas Raiders     6501
# 13      14          LAR       Los Angeles Rams      477
# 14      15          MIA         Miami Dolphins     3948
# 15      16          MIN      Minnesota Vikings     5239
# 16      17           NE   New England Patriots     3738
# 17      18           NO     New Orleans Saints     3493
# 18      19          NYG        New York Giants     3839
# 20      20          NYJ          New York Jets     3839
# 22      21          PHI    Philadelphia Eagles     3806
# 23      22          ARI      Arizona Cardinals     3970
# 24      23          PIT    Pittsburgh Steelers     3752
# 25      24          LAC   Los Angeles Chargers      538
# 26      25           SF    San Francisco 49ers     4738
# 27      26          SEA       Seattle Seahawks     3673
# 28      27           TB   Tampa Bay Buccaneers     3886
# 29      28          WSH  Washington Commanders     3719
# 30      29          CAR      Carolina Panthers     3628
# 31      30          JAX   Jacksonville Jaguars     3712
# 36      33          BAL       Baltimore Ravens     3814
# 37      34          HOU         Houston Texans     3891
#
#                                             Team_logo  \
# 0   https://a.espncdn.com/i/teamlogos/nfl/500/atl.png
# 1   https://a.espncdn.com/i/teamlogos/nfl/500/buf.png
# 2   https://a.espncdn.com/i/teamlogos/nfl/500/chi.png
# 3   https://a.espncdn.com/i/teamlogos/nfl/500/cin.png
# 4   https://a.espncdn.com/i/teamlogos/nfl/500/cle.png
# 5   https://a.espncdn.com/i/teamlogos/nfl/500/dal.png
# 6   https://a.espncdn.com/i/teamlogos/nfl/500/den.png
# 7   https://a.espncdn.com/i/teamlogos/nfl/500/det.png
# 8    https://a.espncdn.com/i/teamlogos/nfl/500/gb.png
# 9   https://a.espncdn.com/i/teamlogos/nfl/500/ten.png
# 10  https://a.espncdn.com/i/teamlogos/nfl/500/ind.png
# 11   https://a.espncdn.com/i/teamlogos/nfl/500/kc.png
# 12   https://a.espncdn.com/i/teamlogos/nfl/500/lv.png
# 13  https://a.espncdn.com/i/teamlogos/nfl/500/lar.png
# 14  https://a.espncdn.com/i/teamlogos/nfl/500/mia.png
# 15  https://a.espncdn.com/i/teamlogos/nfl/500/min.png
# 16   https://a.espncdn.com/i/teamlogos/nfl/500/ne.png
# 17   https://a.espncdn.com/i/teamlogos/nfl/500/no.png
# 18  https://a.espncdn.com/i/teamlogos/nfl/500/nyg.png
# 20  https://a.espncdn.com/i/teamlogos/nfl/500/nyj.png
# 22  https://a.espncdn.com/i/teamlogos/nfl/500/phi.png
# 23  https://a.espncdn.com/i/teamlogos/nfl/500/ari.png
# 24  https://a.espncdn.com/i/teamlogos/nfl/500/pit.png
# 25  https://a.espncdn.com/i/teamlogos/nfl/500/lac.png
# 26   https://a.espncdn.com/i/teamlogos/nfl/500/sf.png
# 27  https://a.espncdn.com/i/teamlogos/nfl/500/sea.png
# 28   https://a.espncdn.com/i/teamlogos/nfl/500/tb.png
# 29  https://a.espncdn.com/i/teamlogos/nfl/500/wsh.png
# 30  https://a.espncdn.com/i/teamlogos/nfl/500/car.png
# 31  https://a.espncdn.com/i/teamlogos/nfl/500/jax.png
# 36  https://a.espncdn.com/i/teamlogos/nfl/500/bal.png
# 37  https://a.espncdn.com/i/teamlogos/nfl/500/hou.png
#
#                          Team_Venue       Venue_City Venue_State  \
# 0             Mercedes-Benz Stadium          Atlanta          GA
# 1                  Highmark Stadium     Orchard Park          NY
# 2                     Soldier Field          Chicago          IL
# 3                    Paycor Stadium       Cincinnati          OH
# 4          Cleveland Browns Stadium        Cleveland          OH
# 5                      AT&T Stadium        Arlington          TX
# 6        Empower Field at Mile High           Denver          CO
# 7                        Ford Field          Detroit          MI
# 8                     Lambeau Field        Green Bay          WI
# 9                    Nissan Stadium        Nashville          TN
# 10                Lucas Oil Stadium     Indianapolis          IN
# 11  GEHA Field at Arrowhead Stadium      Kansas City          MO
# 12                Allegiant Stadium        Las Vegas          NV
# 13    Los Angeles Memorial Coliseum      Los Angeles          CA
# 14                Hard Rock Stadium    Miami Gardens          FL
# 15                U.S. Bank Stadium      Minneapolis          MN
# 16                 Gillette Stadium          Foxboro          MA
# 17                Caesars Superdome      New Orleans          LA
# 18                  MetLife Stadium  East Rutherford          NJ
# 20                  MetLife Stadium  East Rutherford          NJ
# 22          Lincoln Financial Field     Philadelphia          PA
# 23               State Farm Stadium         Glendale          AZ
# 24                 Acrisure Stadium       Pittsburgh          PA
# 25       Dignity Health Sports Park           Carson          CA
# 26                   Levi's Stadium      Santa Clara          CA
# 27                      Lumen Field          Seattle          WA
# 28            Raymond James Stadium            Tampa          FL
# 29                       FedExField         Landover          MD
# 30          Bank of America Stadium        Charlotte          NC
# 31                  TIAA Bank Field     Jacksonville          FL
# 36                 M&T Bank Stadium        Baltimore          MD
# 37                      NRG Stadium          Houston          TX
#
#     Venue_ZipCode Venue_Capacity Venue_Grass Venue_Indoor   Latitude  \
# 0           30313          75000       False         True  33.762932
# 1           14127          71621       False        False  42.763758
# 2           60605          61500        True        False  41.870307
# 3           45202          65515       False        False  39.107778
# 4           44114          67431        True        False  41.506159
# 5           76011         100000       False         True  32.756346
# 6           80204          76125        True        False  39.734908
# 7           48226          64500       False         True  42.332486
# 8           54304          81041        True        False  44.500020
# 9           37213          69143        True        False  36.164167
# 10          46225          63000       False         True  39.742638
# 11          64129          72936        True        False  39.045975
# 12          89118          65000        True         True  36.083811
# 13          90037          77500        True        False  34.004801
# 14          33056          64767        True        False  25.946351
# 15          55415          66468       False         True  44.975929
# 16           2035          65878       False        False  34.066091
# 17          70112          73000       False         True  29.956913
# 18           7073          82500       False        False  42.913398
# 20           7073          82500       False        False  42.913398
# 22          19148          69879        True        False  39.919182
# 23          85305          65000        True         True  33.528296
# 24          15212          68400        True        False  40.467290
# 25          90746          27000       False        False  33.861264
# 26          95054          68500        True        False  37.387439
# 27          98134          68740       False        False  47.578790
# 28          33607          65828        True        False  27.961236
# 29          20785          67617        True        False  38.914669
# 30          28202          73778        True        False  35.227618
# 31          32202          67858        True        False  30.329104
# 36          21230          70745        True        False  39.271259
# 37          77054          71995       False         True  29.686532
#
#      Longitude                                   Location
# 0   -84.396061    (33.76293171583055, -84.39606140301004)
# 1   -78.750270    (42.76375798202035, -78.75026984439712)
# 2   -87.626925   (41.870307417105266, -87.62692521008772)
# 3   -84.510299   (39.107778355093096, -84.51029897382256)
# 4   -81.680961    (41.50615907683215, -81.68096072624114)
# 5   -97.068753                  (32.7563455, -97.0687526)
# 6  -105.025762   (39.73490818177997, -105.02576222527024)
# 7   -83.048996    (42.332486065843625, -83.0489956957476)
# 8   -88.066413    (44.50002035041186, -88.06641305848436)
# 9   -86.765903                 (36.1641665, -86.76590343)
# 10  -86.157089    (39.74263773453725, -86.15708921142776)
# 11  -94.497684    (39.04597513213115, -94.49768449114754)
# 12 -115.214137   (36.08381093012048, -115.21413716024097)
# 13 -118.283782   (34.00480065549133, -118.28378237109825)
# 14  -80.248013   (25.946351299165933, -80.24801250761456)
# 15  -93.259340   (44.975928851086955, -93.25934043586956)
# 16  -95.140489                    (34.066091, -95.140489)
# 17  -90.075298     (29.95691328828125, -90.0752982390625)
# 18  -85.704613                  (42.9133982, -85.7046133)
# 20  -85.704613                  (42.9133982, -85.7046133)
# 22  -75.157703    (39.91918229863248, -75.15770335264956)
# 23 -112.255448   (33.52829563047474, -112.25544751837673)
# 24  -80.008391   (40.467289579837065, -80.00839082922606)
# 25 -118.257125   (33.86126350599174, -118.25712453078513)
# 26 -121.969440   (37.38743902121848, -121.96944016218488)
# 27 -122.332979  (47.578790201629445, -122.33297948883524)
# 28  -82.506283   (27.961236344840763, -82.50628261146497)
# 29  -76.883234    (38.91466939873171, -76.88323352041685)
# 30  -80.842359       (35.227618013333334, -80.8423592072)
# 31  -81.652854    (30.32910428360951, -81.65285396559798)
# 36  -76.623083   (39.271258993451426, -76.62308293303295)
# 37  -95.384010    (29.686531920080323, -95.3840095815261)

# %%
# Save the dataframe to CSV file
teamvenue_cleaned.to_csv('../data/Outputs_CSV/team_venue.csv', index=False)

# %%
# Save the dataframe to JSON file
teamvenue_cleaned.to_json('../data/Outputs_JSON/team_venue.json', indent=4, orient='records')
